# %%
import pandas as pd

# %%
df_voitures  = pd.read_csv("voitures.csv",sep=';')

# %%
df_voitures
# Out:
#     matricule    marque date_ciruclation  kilometrage  cylindre couleur  \
# 0         123       BMW       12/12/2020        50000         8    noir
# 1         124      AUDI       01/02/2023        10000         8    noir
# 2         125        VW       03/02/2022        75000         6   rouge
# 3         126  MERCEDES       20/05/2021       100000         8   blanc
# 4         127        VW       31/12/2019        30000         6   jaune
# 5         128   PEUGEOT       14/02/2020        90000         4    gris
# 6         129      AUDI       01/03/2021        60000         6   rouge
# 7         130   FERRARI       06/06/2016       200000        12   rouge
# 8         131   PEUGEOT       18/05/2017       510000         3    gris
# 9         132        VW       19/04/2020       230000         4   blanc
# 10        133       BMW       19/01/2021        12300         8    bleu
# 11        134   BUGATTI       22/12/2022        13600        12    bleu
# ...
